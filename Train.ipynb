# %%
# !git clone https://github.com/speckean/upar_challenge.git
# %cd upar_challenge
# !python download_datasets.py
# Out:
# Cloning into 'upar_challenge'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 34 (delta 9), reused 16 (delta 4), pack-reused 0
# Receiving objects: 100% (34/34), 139.62 KiB | 1.59 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/upar_challenge
# Download Market 1501 dataset
# Downloading...
# From: https://drive.google.com/uc?id=0B8-rUzbwVRk0c054eEozWG9COHM
# To: /content/upar_challenge/data/market_1501.zip
# 100% 153M/153M [00:01<00:00, 87.6MB/s]
# Extract Market 1501 dataset
# Extracting : 100% 68042/68042 [00:09<00:00, 7412.90it/s]
# Download PA100k dataset
# Retrieving folder list
# Processing file 1dt5nteusNfCVrjAkffLK1sbh4hTLM8tl annotation.zip
# Processing file 1Bod3MrbdCRiSvpR7NSOYi-rF3-ushwtj data.zip
# Processing file 1zmQkoN2YJgbclT990ihj_DYU29YAidey README.txt
# Retrieving folder list completed
# Building directory structure
# ...

# %%
# !pwd
# Out:
# /content/upar_challenge

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/WACV/DFDT
# Out:
# /content/drive/MyDrive/WACV/DFDT

# %%
# !ls
# Out:
# dfdt.png     main_ms	    model      Result  Train.ipynb  venv
# LICENSE.txt  Make_Datasets  README.md  Train   utils

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !python Train/train.py --resume_path "Result/Pretrained/save_1.pth"
# Out:
#   File "/content/drive/MyDrive/WACV/DFDT/Train/train.py", line 202
#     print('Predicting...')
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# !python Train/train.py --resume_path "Result/Pretrained/save_1.pth"
# Out:
# #####/content/drive/MyDrive/WACV/DFDT/Train
# ...

# %%
import pandas as pd

data_path = '/content/drive/MyDrive/WACV/predictions30.csv'
df = pd.read_csv(data_path, index_col=0)

# %%
df.head(5)
# Out:
#                                           # Age-Young  Age-Adult   Age-Old  \
# image_id
# Market1501/query/0001_c1s1_001051_00.jpg     0.001214   0.998656  0.000400
# Market1501/query/0001_c2s1_000301_00.jpg     0.007184   0.995120  0.000932
# Market1501/query/0001_c3s1_000551_00.jpg     0.009483   0.992353  0.000327
# Market1501/query/0001_c4s6_000810_00.jpg     0.001815   0.998216  0.000321
# Market1501/query/0001_c5s1_001426_00.jpg     0.002053   0.998212  0.000253
#
#                                           Gender-Female  Hair-Length-Short  \
# image_id
# Market1501/query/0001_c1s1_001051_00.jpg       0.999842           0.001991
# Market1501/query/0001_c2s1_000301_00.jpg       0.997243           0.007572
# Market1501/query/0001_c3s1_000551_00.jpg       0.999878           0.001801
# Market1501/query/0001_c4s6_000810_00.jpg       0.999777           0.001843
# Market1501/query/0001_c5s1_001426_00.jpg       0.999841           0.002474
#
# ...

# %%
df.index
# Out:
# Index(['Market1501/query/0001_c1s1_001051_00.jpg',
#        'Market1501/query/0001_c2s1_000301_00.jpg',
#        'Market1501/query/0001_c3s1_000551_00.jpg',
#        'Market1501/query/0001_c4s6_000810_00.jpg',
#        'Market1501/query/0001_c5s1_001426_00.jpg',
#        'Market1501/query/0001_c6s1_009601_00.jpg',
#        'Market1501/query/0003_c1s6_015971_00.jpg',
#        'Market1501/query/0003_c3s3_064744_00.jpg',
#        'Market1501/query/0003_c4s6_015641_00.jpg',
#        'Market1501/query/0003_c5s3_065187_00.jpg',
#        ...
#        'PETA/images/18969.png', 'PETA/images/18977.png',
#        'PETA/images/18978.png', 'PETA/images/18981.png',
#        'PETA/images/18984.png', 'PETA/images/18985.png',
#        'PETA/images/18987.png', 'PETA/images/18988.png',
#        'PETA/images/18994.png', 'PETA/images/19000.png'],
#       dtype='object', name='image_id', length=33407)

# %%
import numpy as np
image_path = df.index
predict = df.values

# %%
image_path = np.expand_dims(image_path, axis=1)
result = np.concatenate([image_path, predict], axis=1)

result_df = pd.DataFrame(result)
result_df.to_csv('/content/drive/MyDrive/WACV/predictions.csv', header=False, index=False)

# %%
df.to_csv('/content/drive/MyDrive/WACV/predictions.csv', index=False)

# %%
import pandas as pd

data_path = '/content/drive/MyDrive/WACV/predictions.csv'
df = pd.read_csv(data_path, index_col=0)
df.head(5)
# Out:
#                                           # Age-Young  Age-Adult   Age-Old  \
# image_id
# Market1501/query/0001_c1s1_001051_00.jpg     0.001214   0.998656  0.000400
# Market1501/query/0001_c2s1_000301_00.jpg     0.007184   0.995120  0.000932
# Market1501/query/0001_c3s1_000551_00.jpg     0.009483   0.992353  0.000327
# Market1501/query/0001_c4s6_000810_00.jpg     0.001815   0.998216  0.000321
# Market1501/query/0001_c5s1_001426_00.jpg     0.002053   0.998212  0.000253
#
#                                           Gender-Female  Hair-Length-Short  \
# image_id
# Market1501/query/0001_c1s1_001051_00.jpg       0.999842           0.001991
# Market1501/query/0001_c2s1_000301_00.jpg       0.997243           0.007572
# Market1501/query/0001_c3s1_000551_00.jpg       0.999878           0.001801
# Market1501/query/0001_c4s6_000810_00.jpg       0.999777           0.001843
# Market1501/query/0001_c5s1_001426_00.jpg       0.999841           0.002474
#
# ...

# %%
df.columns
# Out:
# Index(['# Age-Young', 'Age-Adult', 'Age-Old', 'Gender-Female',
#        'Hair-Length-Short', 'Hair-Length-Long', 'Hair-Length-Bald',
#        'UpperBody-Length-Short', 'UpperBody-Color-Black',
#        'UpperBody-Color-Blue', 'UpperBody-Color-Brown',
#        'UpperBody-Color-Green', 'UpperBody-Color-Grey',
#        'UpperBody-Color-Orange', 'UpperBody-Color-Pink',
#        'UpperBody-Color-Purple', 'UpperBody-Color-Red',
#        'UpperBody-Color-White', 'UpperBody-Color-Yellow',
#        'UpperBody-Color-Other', 'LowerBody-Length-Short',
#        'LowerBody-Color-Black', 'LowerBody-Color-Blue',
#        'LowerBody-Color-Brown', 'LowerBody-Color-Green',
#        'LowerBody-Color-Grey', 'LowerBody-Color-Orange',
#        'LowerBody-Color-Pink', 'LowerBody-Color-Purple', 'LowerBody-Color-Red',
#        'LowerBody-Color-White', 'LowerBody-Color-Yellow',
#        'LowerBody-Color-Other', 'LowerBody-Type-Trousers&Shorts',
# ...

# %%
df.index
# Out:
# Index(['Market1501/query/0001_c1s1_001051_00.jpg',
#        'Market1501/query/0001_c2s1_000301_00.jpg',
#        'Market1501/query/0001_c3s1_000551_00.jpg',
#        'Market1501/query/0001_c4s6_000810_00.jpg',
#        'Market1501/query/0001_c5s1_001426_00.jpg',
#        'Market1501/query/0001_c6s1_009601_00.jpg',
#        'Market1501/query/0003_c1s6_015971_00.jpg',
#        'Market1501/query/0003_c3s3_064744_00.jpg',
#        'Market1501/query/0003_c4s6_015641_00.jpg',
#        'Market1501/query/0003_c5s3_065187_00.jpg',
#        ...
#        'PETA/images/18969.png', 'PETA/images/18977.png',
#        'PETA/images/18978.png', 'PETA/images/18981.png',
#        'PETA/images/18984.png', 'PETA/images/18985.png',
#        'PETA/images/18987.png', 'PETA/images/18988.png',
#        'PETA/images/18994.png', 'PETA/images/19000.png'],
#       dtype='object', name='image_id', length=33407)
